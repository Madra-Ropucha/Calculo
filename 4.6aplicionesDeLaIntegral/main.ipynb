# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real=True)

V1 = sp.pi*sp.integrate(sp.sqrt(11**2-x**2)**2,(x,-11,11))
V2 = sp.pi*sp.integrate(sp.sqrt(10**2-x**2)**2,(x,-10,10))

display(V1 - V2)
# Out:
# 1324*pi/3

# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real=True)
y = sp.Symbol('y', real=True)
r = sp.Symbol('r', real=True)

c1 = x**2 + y**2 - 16
c2 = (x - 3)**2 + y**2 - 25

display(c1)
display(c2)

c1 = sp.solve(c1, x)[-1]
c2 = sp.solve(c2, x)[-1]

display(c1)
display(c2)

fExpr = sp.sqrt(r**2-x**2)

v1 = sp.pi * sp.integrate(c2**2 - c1**2, (x, -4, 4))

display(sp.simplify(v1))
# Out:
# x**2 + y**2 - 16
# y**2 + (x - 3)**2 - 25
# sqrt(16 - y**2)
# sqrt(25 - y**2) + 3
# 48*pi*(sqrt(25 - y**2) + 3)

# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real=True)
y = sp.Symbol('y', real=True)

fExpr = 1/x
gExpr = 1/ (1 + x**2)

display(sp.solve(x, fExpr - gExpr))

limite = sp.limit(fExpr, x, 0)
a1 = sp.integrate(fExpr , (x, 1, sp.oo))
a2 = sp.integrate(gExpr , (x, 1, sp.oo))

display(a1)
display(a2)

display(a1 - a2)
# Out:
# []
# oo
# pi/4
# oo

# %%
import sympy as sp

r = sp.Symbol('r', real=True)

fExpr = -1500 + 54 / (1 + r)**1 + 154 / (1 + r)**2 + 454 / (1 + r)**3 + 454 / (1 + r)**4
display(fExpr)

display(sp.solve(fExpr, r))
# Out:
# -1500 + 54/(r + 1) + 154/(r + 1)**2 + 454/(r + 1)**3 + 454/(r + 1)**4
# [-991/1000 - sqrt(-1027729/(5062500*(4923127/9112500000 + sqrt(26810320440083163)/5062500000)**(1/3)) + 154729/2250000 + 2*(4923127/9112500000 + sqrt(26810320440083163)/5062500000)**(1/3))/2 - sqrt(-114195187/(187500000*sqrt(-1027729/(5062500*(4923127/9112500000 + sqrt(26810320440083163)/5062500000)**(1/3)) + 154729/2250000 + 2*(4923127/9112500000 + sqrt(26810320440083163)/5062500000)**(1/3))) - 2*(4923127/9112500000 + sqrt(26810320440083163)/5062500000)**(1/3) + 154729/1125000 + 1027729/(5062500*(4923127/9112500000 + sqrt(26810320440083163)/5062500000)**(1/3)))/2,
# ...
