# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real=True)

V1 = sp.pi*sp.integrate(sp.sqrt(11**2-x**2)**2,(x,-11,11))
V2 = sp.pi*sp.integrate(sp.sqrt(10**2-x**2)**2,(x,-10,10))

display(V1 - V2)
# Out:
# 1324*pi/3

# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real=True)
y = sp.Symbol('y', real=True)
r = sp.Symbol('r', real=True)

c1 = x**2 + y**2 - 16
c2 = (x - 3)**2 + y**2 - 25

display(c1)
display(c2)

c1 = sp.solve(c1, x)[-1]
c2 = sp.solve(c2, x)[-1]

display(c1)
display(c2)

fExpr = sp.sqrt(r**2-x**2)

v1 = sp.pi * sp.integrate(c2**2 - c1**2, (x, -4, 8))

display(sp.simplify(v1))
# Out:
# x**2 + y**2 - 16
# y**2 + (x - 3)**2 - 25
# sqrt(16 - y**2)
# sqrt(25 - y**2) + 3
# 72*pi*(sqrt(25 - y**2) + 3)
