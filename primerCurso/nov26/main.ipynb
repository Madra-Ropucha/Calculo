# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real = True)
f_exp = sp.sin(x)
f = sp.lambdify(x,f_exp)

a = 0; b = np.pi
n = 5

x1 = np.linspace(a,b,n) # aquí guardamos los x_{i}. 
                          # Recuerda que, en Python, se guarda x1[0], x1[1], ..., x1[(n+1)-1] = x1[n]

print(x1)
y1 = f(x1)
print(y1)

h = (b-a)/n # el tamaño de cada subintervalo

aprox_trap = h/2 * (y1[0]+2*np.sum(y1[1:n])+y1[n])
aprox_medio = 2*h * np.sum(y1[1:n:2])
aprox_simpson = 2*h/6 * (y1[0] + 4*np.sum(y1[1:n:2])+2*np.sum(y1[2:n-1:2])+y1[n])

print('aprox_trap: ',aprox_trap) 
print('aprox_medio: ',aprox_medio) 
print('aprox_simpson: ',aprox_simpson) 

print('Exacta: ',b**5/5+b)
# Out:
# [0.         0.78539816 1.57079633 2.35619449 3.14159265]
# [0.00000000e+00 7.07106781e-01 1.00000000e+00 7.07106781e-01
#  1.22464680e-16]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 20
#      16 print(y1)
#      18 h = (b-a)/n # el tamaño de cada subintervalo
# ---> 20 aprox_trap = h/2 * (y1[0]+2*np.sum(y1[1:n])+y1[n])
#      21 aprox_medio = 2*h * np.sum(y1[1:n:2])
#      22 aprox_simpson = 2*h/6 * (y1[0] + 4*np.sum(y1[1:n:2])+2*np.sum(y1[2:n-1:2])+y1[n])
#
# IndexError: index 5 is out of bounds for axis 0 with size 5
